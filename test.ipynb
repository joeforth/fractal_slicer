# %%
from fracprint import processor
from fracprint import writer
import pandas as pd

# Parameters to vary
filedir = './test_files/'  # Directory where the files are stored

# filename, filetype = 'test_squiggle_2d.csv', 'inkscape'
filename, filetype = 'test_squiggle_3d.txt', 'rhino'

x_dim, y_dim = 22., 22.       # x, y dimensions of the container you're printing into
x_trans, y_trans = 0., 0.    # Distance by which to translate the pattern
inlet_d = 0.                 # Length of the inlet / outlet ports in mm
res = 0.1  # Pattern resolution in mm

# x_all_shift, y_all_shift = processor.shape_prep(filedir, filename, x_dim, y_dim, inlet_d, x_trans, y_trans, res)
data = processor.shape_prep(filedir, filename, filetype, x_dim, y_dim, inlet_d, x_trans, y_trans, res)
data

# Next step is to sort lines based on position - waiting on Sara to send shape
# in which line ID is encoded through colour.
# Out:
# Rhino csv file detected
#             x         y    z    r    g    b
# 0    0.900000  0.000000  0.0  200    0    0
# 1    1.000000  0.000000  0.0  200    0    0
# 2   -0.900000  0.000000  0.0  200    0    0
# 3   -1.000000  0.000000  0.0  200    0    0
# 4    0.639206 -0.316260  0.0    0  255    0
# ..        ...       ...  ...  ...  ...  ...
# 190 -0.087749 -0.012726  0.0    0    0  255
# 191 -0.100991 -0.006839  0.0    0    0  255
# 192 -0.114177  0.000032  0.0    0    0  255
# 193 -0.127244  0.007937  0.0    0    0  255
# 194 -0.140126  0.016929  0.0    0    0  255
#
# [195 rows x 6 columns]
